# %%
# Import libraries
from msc_code.scripts.notebook_setup import *
# Out:
# Notebook setup complete.

# %%
# Import full text screening inclusion data
import_path = os.path.join(PROC_DATA_DIR, 'full_text_screen', 'full_text_screen_end_final.csv')
ft_data = pd.read_csv(import_path)
ft_data.head()
# Out:
#    Study_ID  Exclude_JGE  Reason_ID_JGE Unclear_JGE  \
# 0         3         True           12.0         NaN
# 1         4         True            1.0         NaN
# 2         7         True            9.0         NaN
# 3        15         True            9.0         NaN
# 4        21         True            5.0         NaN
#
#                                         Comments_JGE Exclude_MS  Reason_ID_MS  \
# 0  Record of first gastrotomy for intention inges...        NaN           NaN
# 1    Pay wall, unable to access via QMUL or Sci-Hub.        NaN           NaN
# 2  Case series in 'Oesophagus' Section. Intention...        NaN           NaN
# 3  Case series. All children. All appear to be co...        NaN           NaN
# 4                                                NaN        NaN           NaN
#
#   Unclear_MS Comments_MS Exclude_GC  Reason_ID_GC Comments_GC  Exclude_FINAL  \
# 0        NaN         NaN        NaN           NaN         NaN           True
# 1        NaN         NaN        NaN           NaN         NaN           True
# 2        NaN         NaN        NaN           NaN         NaN           True
# 3        NaN         NaN        NaN           NaN         NaN           True
# 4        NaN         NaN        NaN           NaN         NaN           True
#
#    Reason_ID_FINAL
# 0             12.0
# 1              1.0
# 2              9.0
# 3              9.0
# 4              5.0
