# %%
# Import libraries
from msc_code.scripts.notebook_setup import *
# Out:
# Notebook setup complete.

# %%
# Output case data
output_path = os.path.join(PROC_DATA_DIR, "sandbox")

# %%
# Import case data
import_path = os.path.join(RAW_DATA_DIR, "data_extraction", "case_report_data_extraction_end.xlsx")
case_df = pd.read_excel(import_path)

# Import series data
import_path = os.path.join(RAW_DATA_DIR, "data_extraction", "series_data_end.xlsx")
series_df = pd.read_excel(import_path)
