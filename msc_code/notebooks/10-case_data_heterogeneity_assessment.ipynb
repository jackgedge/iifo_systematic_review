# %%
# import library
from msc_code.scripts.notebook_setup import *

# %%
import_path = os.path.join(PROC_DATA_DIR, "data_extraction", "case_data_clean.csv")
case_data = pd.read_csv(import_path)

# %%
import pandas as pd
from scipy.stats import chi2_contingency

def chi_square_test(df, var1, var2):
    # Drop rows where either variable is 'UK'
    df_filtered = df[(df[var1].isin(['Y', 'N'])) & (df[var2].isin(['Y', 'N']))]
    
    # Create contingency table
    table = pd.crosstab(df_filtered[var1], df_filtered[var2])
    
    # Check if the table is 2x2 or larger
    if table.shape[0] < 2 or table.shape[1] < 2:
        print(f"Not enough data to run chi-square for {var1} vs {var2}.")
        return None
    
    # Perform chi-square test
    chi2, p, dof, expected = chi2_contingency(table)
    
    print(f"Chi-square test between {var1} and {var2}:")
    print(f"Chi2 = {chi2:.4f}, p-value = {p:.4f}")
    print("Contingency Table:")
    print(table)
    print("\n")

# Example usage:
# Assuming your data is in a DataFrame called `case_data`
chi_square_test(case_data, 'Motivation_Intent_To_Harm', 'Outcome_Surgery')
# Out:
# Chi-square test between Motivation_Intent_To_Harm and Outcome_Surgery:
# Chi2 = 2.8086, p-value = 0.0938
# Contingency Table:
# Outcome_Surgery             N   Y
# Motivation_Intent_To_Harm
# N                          22  26
# Y                           6  20

# %%
motivation_cols = [col for col in case_data.columns if col.startswith('Motivation') and col != 'Motivation_Other_Long']
motivation_cols
# Out:
# ['Motivation_Intent_To_Harm',
#  'Motivation_Protest',
#  'Motivation_Psychiatric',
#  'Motivation_Psychosocial',
#  'Motivation_Unknown',
#  'Motivation_Other']

# %%
object_cols = [col for col in case_data.columns if col.startswith('Object') and col != 'Object_Other_Long']
object_cols
# Out:
# ['Object_Button_Battery',
#  'Object_Magnet',
#  'Object_Long',
#  'Object_Diameter_Large',
#  'Object_Sharp',
#  'Object_Multiple']

# %%
outcome_cols = [col for col in case_data.columns if col.startswith('Outcome') and col != 'Outcome_Other_Long']
outcome_cols
# Out:
# ['Outcome_Endoscopy',
#  'Outcome_Surgery',
#  'Outcome_Death',
#  'Outcome_Injury_Needing_Intervention',
#  'Outcome_Perforation',
#  'Outcome_Obstruction',
#  'Outcome_Other']

# %%
case_data.columns
# Out:
# Index(['Unnamed: 0', 'Study_ID', 'Patient_ID', 'Age_Yrs', 'Gender',
#        'Is_Intentional', 'Is_Prisoner', 'Is_Psych_Inpat',
#        'Is_Displaced_Person', 'Under_Influence_Alcohol', 'Psych_Hx',
#        'Severe_Disability_Hx', 'Previous_Ingestions',
#        'Motivation_Intent_To_Harm', 'Motivation_Protest',
#        'Motivation_Psychiatric', 'Motivation_Psychosocial',
#        'Motivation_Unknown', 'Motivation_Other', 'Motivation_Other_Long',
#        'Object_Button_Battery', 'Object_Magnet', 'Object_Long',
#        'Object_Diameter_Large', 'Object_Sharp', 'Object_Multiple',
#        'Object_Other_Long', 'Outcome_Endoscopy', 'Outcome_Surgery',
#        'Outcome_Death', 'Outcome_Injury_Needing_Intervention',
#        'Outcome_Perforation', 'Outcome_Obstruction', 'Outcome_Other',
#        'Outcome_Other_Long', 'Comments'],
#       dtype='object')

# %%
population_cols = ['Is_Intentional', 'Is_Prisoner', 'Is_Psych_Inpat', 'Is_Displaced_Person',
                   'Under_Influence_Alcohol', 'Psych_Hx', 'Severe_Disability_Hx',
                   'Previous_Ingestions']
population_cols
# Out:
# ['Is_Intentional',
#  'Is_Prisoner',
#  'Is_Psych_Inpat',
#  'Is_Displaced_Person',
#  'Under_Influence_Alcohol',
#  'Psych_Hx',
#  'Severe_Disability_Hx',
#  'Previous_Ingestions']

# %%
for population in population_cols:
    for outcome in outcome_cols:
        chi_square_test(case_data, population, outcome)
# Out:
# Chi-square test between Is_Intentional and Outcome_Endoscopy:
# Chi2 = 0.0576, p-value = 0.8103
# Contingency Table:
# Outcome_Endoscopy   N   Y
# Is_Intentional
# N                   0   1
# Y                  61  37
#
#
# Chi-square test between Is_Intentional and Outcome_Surgery:
# Chi2 = 0.0476, p-value = 0.8273
# Contingency Table:
# Outcome_Surgery   N   Y
# Is_Intentional
# N                 1   0
# Y                38  60
#
#
# Chi-square test between Is_Intentional and Outcome_Death:
# Chi2 = 0.0000, p-value = 1.0000
# Contingency Table:
# Outcome_Death    N  Y
# Is_Intentional
# N                1  0
# Y               89  7
#
#
# Chi-square test between Is_Intentional and Outcome_Injury_Needing_Intervention:
# Chi2 = 0.0315, p-value = 0.8591
# Contingency Table:
# Outcome_Injury_Needing_Intervention   N   Y
# Is_Intentional
# N                                     1   0
# Y                                    37  54
#
#
# Chi-square test between Is_Intentional and Outcome_Perforation:
# Chi2 = 0.0000, p-value = 1.0000
# Contingency Table:
# Outcome_Perforation   N   Y
# Is_Intentional
# N                     1   0
# Y                    61  27
#
#
# Chi-square test between Is_Intentional and Outcome_Obstruction:
# Chi2 = 0.0000, p-value = 1.0000
# Contingency Table:
# Outcome_Obstruction   N   Y
# Is_Intentional
# N                     1   0
# Y                    72  18
#
#
# Chi-square test between Is_Intentional and Outcome_Other:
# Chi2 = 0.0000, p-value = 1.0000
# Contingency Table:
# Outcome_Other    N   Y
# Is_Intentional
# N                1   0
# Y               59  34
#
#
# Chi-square test between Is_Prisoner and Outcome_Endoscopy:
# Chi2 = 0.0025, p-value = 0.9605
# Contingency Table:
# Outcome_Endoscopy   N   Y
# Is_Prisoner
# N                  49  30
# Y                  10   5
#
#
# Chi-square test between Is_Prisoner and Outcome_Surgery:
# Chi2 = 0.8463, p-value = 0.3576
# Contingency Table:
# Outcome_Surgery   N   Y
# Is_Prisoner
# N                29  50
# Y                 8   7
#
#
# Chi-square test between Is_Prisoner and Outcome_Death:
# Chi2 = 0.4660, p-value = 0.4948
# Contingency Table:
# Outcome_Death   N  Y
# Is_Prisoner
# N              70  7
# Y              15  0
#
#
# Chi-square test between Is_Prisoner and Outcome_Injury_Needing_Intervention:
# Chi2 = 1.0225, p-value = 0.3119
# Contingency Table:
# Outcome_Injury_Needing_Intervention   N   Y
# Is_Prisoner
# N                                    28  45
# Y                                     8   6
#
#
# Chi-square test between Is_Prisoner and Outcome_Perforation:
# Chi2 = 0.0000, p-value = 1.0000
# Contingency Table:
# Outcome_Perforation   N   Y
# Is_Prisoner
# N                    48  22
# Y                     9   5
#
#
# Chi-square test between Is_Prisoner and Outcome_Obstruction:
# Chi2 = 3.0940, p-value = 0.0786
# Contingency Table:
# Outcome_Obstruction   N   Y
# Is_Prisoner
# N                    54  17
# Y                    15   0
#
#
# Chi-square test between Is_Prisoner and Outcome_Other:
# Chi2 = 2.6224, p-value = 0.1054
# Contingency Table:
# Outcome_Other   N   Y
# Is_Prisoner
# N              45  29
# Y              13   2
#
#
# Chi-square test between Is_Psych_Inpat and Outcome_Endoscopy:
# Chi2 = 0.0000, p-value = 1.0000
# Contingency Table:
# Outcome_Endoscopy   N   Y
# Is_Psych_Inpat
# N                  46  26
# Y                   5   2
#
#
# Chi-square test between Is_Psych_Inpat and Outcome_Surgery:
# Chi2 = 0.0000, p-value = 1.0000
# Contingency Table:
# Outcome_Surgery   N   Y
# Is_Psych_Inpat
# N                30  42
# Y                 3   4
#
#
# Chi-square test between Is_Psych_Inpat and Outcome_Death:
# Chi2 = 0.0000, p-value = 1.0000
# Contingency Table:
# Outcome_Death    N  Y
# Is_Psych_Inpat
# N               66  5
# Y                6  1
#
#
# Chi-square test between Is_Psych_Inpat and Outcome_Injury_Needing_Intervention:
# Chi2 = 1.4925, p-value = 0.2218
# Contingency Table:
# Outcome_Injury_Needing_Intervention   N   Y
# Is_Psych_Inpat
# N                                    28  40
# Y                                     4   1
#
#
# Chi-square test between Is_Psych_Inpat and Outcome_Perforation:
# Chi2 = 0.0008, p-value = 0.9777
# Contingency Table:
# Outcome_Perforation   N   Y
# Is_Psych_Inpat
# N                    46  21
# Y                     4   1
#
#
# Chi-square test between Is_Psych_Inpat and Outcome_Obstruction:
# Chi2 = 0.0000, p-value = 1.0000
# Contingency Table:
# Outcome_Obstruction   N   Y
# Is_Psych_Inpat
# N                    56  12
# Y                     5   1
#
#
# Chi-square test between Is_Psych_Inpat and Outcome_Other:
# Chi2 = 0.0000, p-value = 1.0000
# Contingency Table:
# Outcome_Other    N   Y
# Is_Psych_Inpat
# N               46  24
# Y                3   2
#
#
# Chi-square test between Is_Displaced_Person and Outcome_Endoscopy:
# Chi2 = 1.1832, p-value = 0.2767
# Contingency Table:
# Outcome_Endoscopy     N  Y
# Is_Displaced_Person
# N                    14  7
# Y                     0  2
#
#
# Chi-square test between Is_Displaced_Person and Outcome_Surgery:
# Chi2 = 0.0000, p-value = 1.0000
# Contingency Table:
# Outcome_Surgery       N  Y
# Is_Displaced_Person
# N                    12  9
# Y                     1  1
#
#
# Chi-square test between Is_Displaced_Person and Outcome_Death:
# Chi2 = 0.0000, p-value = 1.0000
# Contingency Table:
# Outcome_Death         N  Y
# Is_Displaced_Person
# N                    19  2
# Y                     2  0
#
#
# Chi-square test between Is_Displaced_Person and Outcome_Injury_Needing_Intervention:
# Chi2 = 0.0000, p-value = 1.0000
# Contingency Table:
# Outcome_Injury_Needing_Intervention   N  Y
# Is_Displaced_Person
# N                                    11  9
# Y                                     1  1
#
#
# Chi-square test between Is_Displaced_Person and Outcome_Perforation:
# Chi2 = 0.0000, p-value = 1.0000
# Contingency Table:
# Outcome_Perforation   N  Y
# Is_Displaced_Person
# N                    15  5
# Y                     1  1
#
#
# Chi-square test between Is_Displaced_Person and Outcome_Obstruction:
# Chi2 = 0.0000, p-value = 1.0000
# Contingency Table:
# Outcome_Obstruction   N  Y
# Is_Displaced_Person
# N                    17  4
# Y                     2  0
#
#
# Chi-square test between Is_Displaced_Person and Outcome_Other:
# Chi2 = 0.0471, p-value = 0.8281
# Contingency Table:
# Outcome_Other         N  Y
# Is_Displaced_Person
# N                    13  7
# Y                     2  0
#
#
# Chi-square test between Under_Influence_Alcohol and Outcome_Endoscopy:
# Chi2 = 0.0000, p-value = 1.0000
# Contingency Table:
# Outcome_Endoscopy         N   Y
# Under_Influence_Alcohol
# N                        35  14
# Y                         3   1
#
#
# Chi-square test between Under_Influence_Alcohol and Outcome_Surgery:
# Chi2 = 0.0000, p-value = 1.0000
# Contingency Table:
# Outcome_Surgery           N   Y
# Under_Influence_Alcohol
# N                        15  34
# Y                         1   3
#
#
# Chi-square test between Under_Influence_Alcohol and Outcome_Death:
# Chi2 = 0.0000, p-value = 1.0000
# Contingency Table:
# Outcome_Death             N  Y
# Under_Influence_Alcohol
# N                        42  6
# Y                         4  0
#
#
# Chi-square test between Under_Influence_Alcohol and Outcome_Injury_Needing_Intervention:
# Chi2 = 0.0012, p-value = 0.9726
# Contingency Table:
# Outcome_Injury_Needing_Intervention   N   Y
# Under_Influence_Alcohol
# N                                    17  26
# Y                                     1   3
#
#
# Chi-square test between Under_Influence_Alcohol and Outcome_Perforation:
# Chi2 = 0.0049, p-value = 0.9443
# Contingency Table:
# Outcome_Perforation       N   Y
# Under_Influence_Alcohol
# N                        25  17
# Y                         3   1
#
#
# Chi-square test between Under_Influence_Alcohol and Outcome_Obstruction:
# Chi2 = 0.7349, p-value = 0.3913
# Contingency Table:
# Outcome_Obstruction       N  Y
# Under_Influence_Alcohol
# N                        36  8
# Y                         2  2
#
#
# Chi-square test between Under_Influence_Alcohol and Outcome_Other:
# Chi2 = 0.0465, p-value = 0.8292
# Contingency Table:
# Outcome_Other             N   Y
# Under_Influence_Alcohol
# N                        31  14
# Y                         2   2
#
#
# Chi-square test between Psych_Hx and Outcome_Endoscopy:
# Chi2 = 0.0007, p-value = 0.9783
# Contingency Table:
# Outcome_Endoscopy   N   Y
# Psych_Hx
# N                  22  14
# Y                  31  22
#
#
# Chi-square test between Psych_Hx and Outcome_Surgery:
# Chi2 = 0.0418, p-value = 0.8381
# Contingency Table:
# Outcome_Surgery   N   Y
# Psych_Hx
# N                14  22
# Y                23  30
#
#
# Chi-square test between Psych_Hx and Outcome_Death:
# Chi2 = 0.0000, p-value = 1.0000
# Contingency Table:
# Outcome_Death   N  Y
# Psych_Hx
# N              33  3
# Y              47  4
#
#
# Chi-square test between Psych_Hx and Outcome_Injury_Needing_Intervention:
# Chi2 = 0.0869, p-value = 0.7681
# Contingency Table:
# Outcome_Injury_Needing_Intervention   N   Y
# Psych_Hx
# N                                    14  20
# Y                                    23  26
#
#
# Chi-square test between Psych_Hx and Outcome_Perforation:
# Chi2 = 0.8996, p-value = 0.3429
# Contingency Table:
# Outcome_Perforation   N   Y
# Psych_Hx
# N                    22  11
# Y                    37  10
#
#
# Chi-square test between Psych_Hx and Outcome_Obstruction:
# Chi2 = 1.3889, p-value = 0.2386
# Contingency Table:
# Outcome_Obstruction   N   Y
# Psych_Hx
# N                    23  10
# Y                    40   8
#
#
# Chi-square test between Psych_Hx and Outcome_Other:
# Chi2 = 0.2329, p-value = 0.6294
# Contingency Table:
# Outcome_Other   N   Y
# Psych_Hx
# N              23  11
# Y              30  20
#
#
# Chi-square test between Severe_Disability_Hx and Outcome_Endoscopy:
# Chi2 = 2.7691, p-value = 0.0961
# Contingency Table:
# Outcome_Endoscopy      N   Y
# Severe_Disability_Hx
# N                     48  28
# Y                      3   7
#
#
# Chi-square test between Severe_Disability_Hx and Outcome_Surgery:
# Chi2 = 0.0000, p-value = 1.0000
# Contingency Table:
# Outcome_Surgery        N   Y
# Severe_Disability_Hx
# N                     33  43
# Y                      4   6
#
#
# Chi-square test between Severe_Disability_Hx and Outcome_Death:
# Chi2 = 0.0673, p-value = 0.7954
# Contingency Table:
# Outcome_Death          N  Y
# Severe_Disability_Hx
# N                     72  2
# Y                      9  1
#
#
# Chi-square test between Severe_Disability_Hx and Outcome_Injury_Needing_Intervention:
# Chi2 = 0.0396, p-value = 0.8423
# Contingency Table:
# Outcome_Injury_Needing_Intervention   N   Y
# Severe_Disability_Hx
# N                                    31  41
# Y                                     3   6
#
#
# Chi-square test between Severe_Disability_Hx and Outcome_Perforation:
# Chi2 = 0.0000, p-value = 1.0000
# Contingency Table:
# Outcome_Perforation    N   Y
# Severe_Disability_Hx
# N                     50  21
# Y                      6   2
#
#
# Chi-square test between Severe_Disability_Hx and Outcome_Obstruction:
# Chi2 = 0.2815, p-value = 0.5957
# Contingency Table:
# Outcome_Obstruction    N   Y
# Severe_Disability_Hx
# N                     58  14
# Y                      6   3
#
#
# Chi-square test between Severe_Disability_Hx and Outcome_Other:
# Chi2 = 0.1088, p-value = 0.7416
# Contingency Table:
# Outcome_Other          N   Y
# Severe_Disability_Hx
# N                     46  28
# Y                      6   2
#
#
# Chi-square test between Previous_Ingestions and Outcome_Endoscopy:
# Chi2 = 0.0000, p-value = 1.0000
# Contingency Table:
# Outcome_Endoscopy     N   Y
# Previous_Ingestions
# N                    19  15
# Y                    15  11
#
#
# Chi-square test between Previous_Ingestions and Outcome_Surgery:
# Chi2 = 0.0679, p-value = 0.7945
# Contingency Table:
# Outcome_Surgery       N   Y
# Previous_Ingestions
# N                    16  18
# Y                    14  12
#
#
# Chi-square test between Previous_Ingestions and Outcome_Death:
# Chi2 = 0.0572, p-value = 0.8110
# Contingency Table:
# Outcome_Death         N  Y
# Previous_Ingestions
# N                    33  1
# Y                    24  2
#
#
# Chi-square test between Previous_Ingestions and Outcome_Injury_Needing_Intervention:
# Chi2 = 2.1598, p-value = 0.1417
# Contingency Table:
# Outcome_Injury_Needing_Intervention   N   Y
# Previous_Ingestions
# N                                    12  22
# Y                                    14  10
#
#
# Chi-square test between Previous_Ingestions and Outcome_Perforation:
# Chi2 = 0.6491, p-value = 0.4205
# Contingency Table:
# Outcome_Perforation   N   Y
# Previous_Ingestions
# N                    24  10
# Y                    20   4
#
#
# Chi-square test between Previous_Ingestions and Outcome_Obstruction:
# Chi2 = 2.9860, p-value = 0.0840
# Contingency Table:
# Outcome_Obstruction   N   Y
# Previous_Ingestions
# N                    22  12
# Y                    22   3
#
#
# Chi-square test between Previous_Ingestions and Outcome_Other:
# Chi2 = 0.6001, p-value = 0.4386
# Contingency Table:
# Outcome_Other         N   Y
# Previous_Ingestions
# N                    18  16
# Y                    16   8

# %%
for object in object_cols:
    for outcome in outcome_cols:
        chi_square_test(case_data, object, outcome)
# Out:
# Chi-square test between Object_Button_Battery and Outcome_Endoscopy:
# Chi2 = 1.1285, p-value = 0.2881
# Contingency Table:
# Outcome_Endoscopy       N   Y
# Object_Button_Battery
# N                      60  36
# Y                       0   2
#
#
# Chi-square test between Object_Button_Battery and Outcome_Surgery:
# Chi2 = 1.1285, p-value = 0.2881
# Contingency Table:
# Outcome_Surgery         N   Y
# Object_Button_Battery
# N                      36  60
# Y                       2   0
#
#
# Chi-square test between Object_Button_Battery and Outcome_Death:
# Chi2 = 0.0000, p-value = 1.0000
# Contingency Table:
# Outcome_Death           N  Y
# Object_Button_Battery
# N                      88  6
# Y                       2  0
#
#
# Chi-square test between Object_Button_Battery and Outcome_Injury_Needing_Intervention:
# Chi2 = 0.2242, p-value = 0.6359
# Contingency Table:
# Outcome_Injury_Needing_Intervention   N   Y
# Object_Button_Battery
# N                                    38  52
# Y                                     0   2
#
#
# Chi-square test between Object_Button_Battery and Outcome_Perforation:
# Chi2 = 0.0276, p-value = 0.8681
# Contingency Table:
# Outcome_Perforation     N   Y
# Object_Button_Battery
# N                      60  27
# Y                       2   0
#
#
# Chi-square test between Object_Button_Battery and Outcome_Obstruction:
# Chi2 = 0.0499, p-value = 0.8233
# Contingency Table:
# Outcome_Obstruction     N   Y
# Object_Button_Battery
# N                      72  16
# Y                       1   1
#
#
# Chi-square test between Object_Button_Battery and Outcome_Other:
# Chi2 = 0.0000, p-value = 1.0000
# Contingency Table:
# Outcome_Other           N   Y
# Object_Button_Battery
# N                      59  33
# Y                       1   1
#
#
# Chi-square test between Object_Magnet and Outcome_Endoscopy:
# Chi2 = 0.0238, p-value = 0.8775
# Contingency Table:
# Outcome_Endoscopy   N   Y
# Object_Magnet
# N                  54  33
# Y                   6   5
#
#
# Chi-square test between Object_Magnet and Outcome_Surgery:
# Chi2 = 1.3442, p-value = 0.2463
# Contingency Table:
# Outcome_Surgery   N   Y
# Object_Magnet
# N                36  51
# Y                 2   9
#
#
# Chi-square test between Object_Magnet and Outcome_Death:
# Chi2 = 0.0298, p-value = 0.8630
# Contingency Table:
# Outcome_Death   N  Y
# Object_Magnet
# N              80  6
# Y              10  0
#
#
# Chi-square test between Object_Magnet and Outcome_Injury_Needing_Intervention:
# Chi2 = 3.9450, p-value = 0.0470
# Contingency Table:
# Outcome_Injury_Needing_Intervention   N   Y
# Object_Magnet
# N                                    37  44
# Y                                     1  10
#
#
# Chi-square test between Object_Magnet and Outcome_Perforation:
# Chi2 = 0.6638, p-value = 0.4152
# Contingency Table:
# Outcome_Perforation   N   Y
# Object_Magnet
# N                    56  22
# Y                     6   5
#
#
# Chi-square test between Object_Magnet and Outcome_Obstruction:
# Chi2 = 1.3673, p-value = 0.2423
# Contingency Table:
# Outcome_Obstruction   N   Y
# Object_Magnet
# N                    66  13
# Y                     7   4
#
#
# Chi-square test between Object_Magnet and Outcome_Other:
# Chi2 = 2.8348, p-value = 0.0922
# Contingency Table:
# Outcome_Other   N   Y
# Object_Magnet
# N              56  27
# Y               4   7
#
#
# Chi-square test between Object_Long and Outcome_Endoscopy:
# Chi2 = 2.4020, p-value = 0.1212
# Contingency Table:
# Outcome_Endoscopy   N   Y
# Object_Long
# N                  24  23
# Y                  33  15
#
#
# Chi-square test between Object_Long and Outcome_Surgery:
# Chi2 = 5.7919, p-value = 0.0161
# Contingency Table:
# Outcome_Surgery   N   Y
# Object_Long
# N                24  23
# Y                12  36
#
#
# Chi-square test between Object_Long and Outcome_Death:
# Chi2 = 1.6733, p-value = 0.1958
# Contingency Table:
# Outcome_Death   N  Y
# Object_Long
# N              46  1
# Y              41  5
#
#
# Chi-square test between Object_Long and Outcome_Injury_Needing_Intervention:
# Chi2 = 3.3178, p-value = 0.0685
# Contingency Table:
# Outcome_Injury_Needing_Intervention   N   Y
# Object_Long
# N                                    22  22
# Y                                    13  32
#
#
# Chi-square test between Object_Long and Outcome_Perforation:
# Chi2 = 1.9435, p-value = 0.1633
# Contingency Table:
# Outcome_Perforation   N   Y
# Object_Long
# N                    33  10
# Y                    26  17
#
#
# Chi-square test between Object_Long and Outcome_Obstruction:
# Chi2 = 0.0000, p-value = 1.0000
# Contingency Table:
# Outcome_Obstruction   N  Y
# Object_Long
# N                    35  9
# Y                    35  8
#
#
# Chi-square test between Object_Long and Outcome_Other:
# Chi2 = 0.1660, p-value = 0.6837
# Contingency Table:
# Outcome_Other   N   Y
# Object_Long
# N              29  15
# Y              28  19
#
#
# Chi-square test between Object_Diameter_Large and Outcome_Endoscopy:
# Chi2 = 0.0000, p-value = 1.0000
# Contingency Table:
# Outcome_Endoscopy       N   Y
# Object_Diameter_Large
# N                      16  11
# Y                      41  26
#
#
# Chi-square test between Object_Diameter_Large and Outcome_Surgery:
# Chi2 = 2.6416, p-value = 0.1041
# Contingency Table:
# Outcome_Surgery         N   Y
# Object_Diameter_Large
# N                      14  13
# Y                      21  46
#
#
# Chi-square test between Object_Diameter_Large and Outcome_Death:
# Chi2 = 1.3670, p-value = 0.2423
# Contingency Table:
# Outcome_Death           N  Y
# Object_Diameter_Large
# N                      27  0
# Y                      59  6
#
#
# Chi-square test between Object_Diameter_Large and Outcome_Injury_Needing_Intervention:
# Chi2 = 0.1666, p-value = 0.6831
# Contingency Table:
# Outcome_Injury_Needing_Intervention   N   Y
# Object_Diameter_Large
# N                                    11  14
# Y                                    23  40
#
#
# Chi-square test between Object_Diameter_Large and Outcome_Perforation:
# Chi2 = 6.4090, p-value = 0.0114
# Contingency Table:
# Outcome_Perforation     N   Y
# Object_Diameter_Large
# N                      22   2
# Y                      37  24
#
#
# Chi-square test between Object_Diameter_Large and Outcome_Obstruction:
# Chi2 = 5.1405, p-value = 0.0234
# Contingency Table:
# Outcome_Obstruction     N  Y
# Object_Diameter_Large
# N                      15  9
# Y                      54  8
#
#
# Chi-square test between Object_Diameter_Large and Outcome_Other:
# Chi2 = 0.4966, p-value = 0.4810
# Contingency Table:
# Outcome_Other           N   Y
# Object_Diameter_Large
# N                      13  11
# Y                      43  23
#
#
# Chi-square test between Object_Sharp and Outcome_Endoscopy:
# Chi2 = 2.6922, p-value = 0.1008
# Contingency Table:
# Outcome_Endoscopy   N   Y
# Object_Sharp
# N                  24  24
# Y                  31  14
#
#
# Chi-square test between Object_Sharp and Outcome_Surgery:
# Chi2 = 0.3539, p-value = 0.5519
# Contingency Table:
# Outcome_Surgery   N   Y
# Object_Sharp
# N                21  27
# Y                16  29
#
#
# Chi-square test between Object_Sharp and Outcome_Death:
# Chi2 = 0.2563, p-value = 0.6127
# Contingency Table:
# Outcome_Death   N  Y
# Object_Sharp
# N              45  2
# Y              40  4
#
#
# Chi-square test between Object_Sharp and Outcome_Injury_Needing_Intervention:
# Chi2 = 0.5330, p-value = 0.4654
# Contingency Table:
# Outcome_Injury_Needing_Intervention   N   Y
# Object_Sharp
# N                                    21  25
# Y                                    15  27
#
#
# Chi-square test between Object_Sharp and Outcome_Perforation:
# Chi2 = 0.5735, p-value = 0.4489
# Contingency Table:
# Outcome_Perforation   N   Y
# Object_Sharp
# N                    33  12
# Y                    26  15
#
#
# Chi-square test between Object_Sharp and Outcome_Obstruction:
# Chi2 = 2.1453, p-value = 0.1430
# Contingency Table:
# Outcome_Obstruction   N   Y
# Object_Sharp
# N                    33  12
# Y                    37   5
#
#
# Chi-square test between Object_Sharp and Outcome_Other:
# Chi2 = 0.0000, p-value = 1.0000
# Contingency Table:
# Outcome_Other   N   Y
# Object_Sharp
# N              30  16
# Y              28  16
#
#
# Chi-square test between Object_Multiple and Outcome_Endoscopy:
# Chi2 = 0.0334, p-value = 0.8549
# Contingency Table:
# Outcome_Endoscopy   N   Y
# Object_Multiple
# N                  26  18
# Y                  34  20
#
#
# Chi-square test between Object_Multiple and Outcome_Surgery:
# Chi2 = 1.1397, p-value = 0.2857
# Contingency Table:
# Outcome_Surgery   N   Y
# Object_Multiple
# N                14  30
# Y                24  30
#
#
# Chi-square test between Object_Multiple and Outcome_Death:
# Chi2 = 0.0000, p-value = 1.0000
# Contingency Table:
# Outcome_Death     N  Y
# Object_Multiple
# N                40  3
# Y                50  3
#
#
# Chi-square test between Object_Multiple and Outcome_Injury_Needing_Intervention:
# Chi2 = 0.4446, p-value = 0.5049
# Contingency Table:
# Outcome_Injury_Needing_Intervention   N   Y
# Object_Multiple
# N                                    19  22
# Y                                    19  32
#
#
# Chi-square test between Object_Multiple and Outcome_Perforation:
# Chi2 = 0.8938, p-value = 0.3445
# Contingency Table:
# Outcome_Perforation   N   Y
# Object_Multiple
# N                    29   9
# Y                    33  18
#
#
# Chi-square test between Object_Multiple and Outcome_Obstruction:
# Chi2 = 1.0291, p-value = 0.3104
# Contingency Table:
# Outcome_Obstruction   N   Y
# Object_Multiple
# N                    34   5
# Y                    39  12
#
#
# Chi-square test between Object_Multiple and Outcome_Other:
# Chi2 = 0.0000, p-value = 1.0000
# Contingency Table:
# Outcome_Other     N   Y
# Object_Multiple
# N                27  15
# Y                33  19

# %%
for motivation in motivation_cols:
    for outcome in outcome_cols:
        chi_square_test(case_data, motivation, outcome)
# Out:
# Chi-square test between Motivation_Intent_To_Harm and Outcome_Endoscopy:
# Chi2 = 0.1050, p-value = 0.7460
# Contingency Table:
# Outcome_Endoscopy           N   Y
# Motivation_Intent_To_Harm
# N                          30  18
# Y                          18   8
#
#
# Chi-square test between Motivation_Intent_To_Harm and Outcome_Surgery:
# Chi2 = 2.8086, p-value = 0.0938
# Contingency Table:
# Outcome_Surgery             N   Y
# Motivation_Intent_To_Harm
# N                          22  26
# Y                           6  20
#
#
# Chi-square test between Motivation_Intent_To_Harm and Outcome_Death:
# Chi2 = 1.4014, p-value = 0.2365
# Contingency Table:
# Outcome_Death               N  Y
# Motivation_Intent_To_Harm
# N                          43  5
# Y                          25  0
#
#
# Chi-square test between Motivation_Intent_To_Harm and Outcome_Injury_Needing_Intervention:
# Chi2 = 0.0206, p-value = 0.8858
# Contingency Table:
# Outcome_Injury_Needing_Intervention   N   Y
# Motivation_Intent_To_Harm
# N                                    21  24
# Y                                    10  14
#
#
# Chi-square test between Motivation_Intent_To_Harm and Outcome_Perforation:
# Chi2 = 0.0485, p-value = 0.8256
# Contingency Table:
# Outcome_Perforation         N   Y
# Motivation_Intent_To_Harm
# N                          32  13
# Y                          15   8
#
#
# Chi-square test between Motivation_Intent_To_Harm and Outcome_Obstruction:
# Chi2 = 4.3156, p-value = 0.0378
# Contingency Table:
# Outcome_Obstruction         N   Y
# Motivation_Intent_To_Harm
# N                          33  13
# Y                          23   1
#
#
# Chi-square test between Motivation_Intent_To_Harm and Outcome_Other:
# Chi2 = 0.5537, p-value = 0.4568
# Contingency Table:
# Outcome_Other               N   Y
# Motivation_Intent_To_Harm
# N                          33  13
# Y                          15  10
#
#
# Chi-square test between Motivation_Protest and Outcome_Endoscopy:
# Chi2 = 0.8254, p-value = 0.3636
# Contingency Table:
# Outcome_Endoscopy    N   Y
# Motivation_Protest
# N                   44  30
# Y                    8   2
#
#
# Chi-square test between Motivation_Protest and Outcome_Surgery:
# Chi2 = 0.8254, p-value = 0.3636
# Contingency Table:
# Outcome_Surgery      N   Y
# Motivation_Protest
# N                   30  44
# Y                    2   8
#
#
# Chi-square test between Motivation_Protest and Outcome_Death:
# Chi2 = 0.0240, p-value = 0.8770
# Contingency Table:
# Outcome_Death        N  Y
# Motivation_Protest
# N                   67  5
# Y                   10  0
#
#
# Chi-square test between Motivation_Protest and Outcome_Injury_Needing_Intervention:
# Chi2 = 2.9991, p-value = 0.0833
# Contingency Table:
# Outcome_Injury_Needing_Intervention   N   Y
# Motivation_Protest
# N                                    33  36
# Y                                     1   8
#
#
# Chi-square test between Motivation_Protest and Outcome_Perforation:
# Chi2 = 4.2588, p-value = 0.0390
# Contingency Table:
# Outcome_Perforation   N   Y
# Motivation_Protest
# N                    50  18
# Y                     3   6
#
#
# Chi-square test between Motivation_Protest and Outcome_Obstruction:
# Chi2 = 0.0000, p-value = 1.0000
# Contingency Table:
# Outcome_Obstruction   N   Y
# Motivation_Protest
# N                    56  13
# Y                     8   2
#
#
# Chi-square test between Motivation_Protest and Outcome_Other:
# Chi2 = 1.9313, p-value = 0.1646
# Contingency Table:
# Outcome_Other        N   Y
# Motivation_Protest
# N                   44  27
# Y                    9   1
#
#
# Chi-square test between Motivation_Psychiatric and Outcome_Endoscopy:
# Chi2 = 0.9278, p-value = 0.3354
# Contingency Table:
# Outcome_Endoscopy        N   Y
# Motivation_Psychiatric
# N                       31  14
# Y                       28  21
#
#
# Chi-square test between Motivation_Psychiatric and Outcome_Surgery:
# Chi2 = 3.1698, p-value = 0.0750
# Contingency Table:
# Outcome_Surgery          N   Y
# Motivation_Psychiatric
# N                       13  32
# Y                       24  25
#
#
# Chi-square test between Motivation_Psychiatric and Outcome_Death:
# Chi2 = 0.0000, p-value = 1.0000
# Contingency Table:
# Outcome_Death            N  Y
# Motivation_Psychiatric
# N                       42  3
# Y                       43  4
#
#
# Chi-square test between Motivation_Psychiatric and Outcome_Injury_Needing_Intervention:
# Chi2 = 0.1467, p-value = 0.7017
# Contingency Table:
# Outcome_Injury_Needing_Intervention   N   Y
# Motivation_Psychiatric
# N                                    16  26
# Y                                    20  25
#
#
# Chi-square test between Motivation_Psychiatric and Outcome_Perforation:
# Chi2 = 1.9428, p-value = 0.1634
# Contingency Table:
# Outcome_Perforation      N   Y
# Motivation_Psychiatric
# N                       25  16
# Y                       34  10
#
#
# Chi-square test between Motivation_Psychiatric and Outcome_Obstruction:
# Chi2 = 0.1842, p-value = 0.6678
# Contingency Table:
# Outcome_Obstruction      N   Y
# Motivation_Psychiatric
# N                       32  10
# Y                       37   8
#
#
# Chi-square test between Motivation_Psychiatric and Outcome_Other:
# Chi2 = 0.2542, p-value = 0.6142
# Contingency Table:
# Outcome_Other            N   Y
# Motivation_Psychiatric
# N                       30  14
# Y                       28  18
#
#
# Chi-square test between Motivation_Psychosocial and Outcome_Endoscopy:
# Chi2 = 0.2381, p-value = 0.6256
# Contingency Table:
# Outcome_Endoscopy         N   Y
# Motivation_Psychosocial
# N                        40  27
# Y                        17   8
#
#
# Chi-square test between Motivation_Psychosocial and Outcome_Surgery:
# Chi2 = 0.0000, p-value = 1.0000
# Contingency Table:
# Outcome_Surgery           N   Y
# Motivation_Psychosocial
# N                        26  41
# Y                        10  15
#
#
# Chi-square test between Motivation_Psychosocial and Outcome_Death:
# Chi2 = 0.1525, p-value = 0.6961
# Contingency Table:
# Outcome_Death             N  Y
# Motivation_Psychosocial
# N                        59  6
# Y                        24  1
#
#
# Chi-square test between Motivation_Psychosocial and Outcome_Injury_Needing_Intervention:
# Chi2 = 0.0578, p-value = 0.8100
# Contingency Table:
# Outcome_Injury_Needing_Intervention   N   Y
# Motivation_Psychosocial
# N                                    26  36
# Y                                    11  12
#
#
# Chi-square test between Motivation_Psychosocial and Outcome_Perforation:
# Chi2 = 0.0936, p-value = 0.7597
# Contingency Table:
# Outcome_Perforation       N   Y
# Motivation_Psychosocial
# N                        43  17
# Y                        15   8
#
#
# Chi-square test between Motivation_Psychosocial and Outcome_Obstruction:
# Chi2 = 3.1331, p-value = 0.0767
# Contingency Table:
# Outcome_Obstruction       N  Y
# Motivation_Psychosocial
# N                        53  9
# Y                        15  8
#
#
# Chi-square test between Motivation_Psychosocial and Outcome_Other:
# Chi2 = 0.7212, p-value = 0.3957
# Contingency Table:
# Outcome_Other             N   Y
# Motivation_Psychosocial
# N                        40  24
# Y                        18   6
#
#
# Not enough data to run chi-square for Motivation_Unknown vs Outcome_Endoscopy.
# Not enough data to run chi-square for Motivation_Unknown vs Outcome_Surgery.
# Not enough data to run chi-square for Motivation_Unknown vs Outcome_Death.
# Not enough data to run chi-square for Motivation_Unknown vs Outcome_Injury_Needing_Intervention.
# Not enough data to run chi-square for Motivation_Unknown vs Outcome_Perforation.
# Not enough data to run chi-square for Motivation_Unknown vs Outcome_Obstruction.
# Not enough data to run chi-square for Motivation_Unknown vs Outcome_Other.
# Chi-square test between Motivation_Other and Outcome_Endoscopy:
# Chi2 = 0.7060, p-value = 0.4008
# Contingency Table:
# Outcome_Endoscopy   N   Y
# Motivation_Other
# N                  56  32
# Y                   5   6
#
#
# Chi-square test between Motivation_Other and Outcome_Surgery:
# Chi2 = 2.0109, p-value = 0.1562
# Contingency Table:
# Outcome_Surgery    N   Y
# Motivation_Other
# N                 32  56
# Y                  7   4
#
#
# Chi-square test between Motivation_Other and Outcome_Death:
# Chi2 = 4.4580, p-value = 0.0347
# Contingency Table:
# Outcome_Death      N  Y
# Motivation_Other
# N                 82  4
# Y                  8  3
#
#
# Chi-square test between Motivation_Other and Outcome_Injury_Needing_Intervention:
# Chi2 = 0.3897, p-value = 0.5325
# Contingency Table:
# Outcome_Injury_Needing_Intervention   N   Y
# Motivation_Other
# N                                    32  49
# Y                                     6   5
#
#
# Chi-square test between Motivation_Other and Outcome_Perforation:
# Chi2 = 0.1518, p-value = 0.6968
# Contingency Table:
# Outcome_Perforation   N   Y
# Motivation_Other
# N                    54  25
# Y                     8   2
#
#
# Chi-square test between Motivation_Other and Outcome_Obstruction:
# Chi2 = 1.5467, p-value = 0.2136
# Contingency Table:
# Outcome_Obstruction   N   Y
# Motivation_Other
# N                    63  18
# Y                    10   0
#
#
# Chi-square test between Motivation_Other and Outcome_Other:
# Chi2 = 0.0000, p-value = 1.0000
# Contingency Table:
# Outcome_Other      N   Y
# Motivation_Other
# N                 53  30
# Y                  7   4
