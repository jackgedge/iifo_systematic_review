# %% [markdown]
# # Bibliography Search
#
# **Author:** Jack Galbraith-Edge

# %%
# Import notebook setup
from msc_code.scripts.notebook_setup import *
# Out:
# Notebook setup complete.

# %%
# Import Title and Abstract Screening Results
title_abstract_screened = pd.read_csv("/".join([PROC_DATA_DIR, "title_abstract_review", "title_abstract_review_complete.csv"]))

title_abstract_screened['TA_Exclude_FINAL'] = title_abstract_screened.apply(
    lambda row: row['Exclude_JGE']
    if pd.isna(row['Exclude_MS'])  # If MS is NaN, take JGE's decision
    else (row['Exclude_JGE']
          if row['Exclude_JGE'] == row['Exclude_MS']  # If JGE and MS agree
          else row['Exclude_GC']),  # If JGE and MS disagree, take GC's decision
    axis=1
)

title_abstract_screened = title_abstract_screened.drop('Unnamed: 0', axis=1)

title_abstract_screened = title_abstract_screened.rename(columns={
    'Exclude_JGE': 'TA_Exclude_JGE',
    'Reason ID_JGE': 'TA_Reason ID_JGE',
    'Exclude_MS': 'TA_Exclude_MS',
    'Reason ID_MS': 'TA_Reason ID_MS',
    'Exclude_GC': 'TA_Exclude_GC',
    'Reason ID_GC': 'TA_Reason ID_GC', 
    'Review_GC': 'TA_Review_GC',
    'Comments_GC': 'TA_Comments_GC'
})

jge_full_text_screened = pd.read_csv(
    "/".join([RAW_DATA_DIR, "full_text_screen", "full_text_screen_end_jge.csv"])
)

jge_full_text_screened = jge_full_text_screened.rename(columns={
    'Exclude': 'FT_Exclude_JGE',
    'Reason ID': 'FT_Reason ID_JGE',
    'Paediatric': 'FT_Paediatric_JGE',
    'Intention Reported': 'FT_Intention Reported_JGE',
    'Deliberate intention': 'FT_Deliberate Intention_JGE',
    'Unclear': 'FT_Unclear_JGE',
    'Accessed': 'FT_Accessed_JGE',
    'Comments': 'FT_Comments_JGE'
})

# Select certain columns from results that have undergone fulltext screening by JGE.
jge_full_text_screened = jge_full_text_screened[['id', 'FT_Exclude_JGE', 'FT_Reason ID_JGE', 'FT_Paediatric_JGE',
       'FT_Intention Reported_JGE', 'FT_Deliberate Intention_JGE',
       'FT_Unclear_JGE', 'FT_Accessed_JGE', 'FT_Comments_JGE']]

# Merge dataframes
screening_results = pd.merge(
    title_abstract_screened,
    jge_full_text_screened,
    how='left', 
    on='id'
)

# Create dataframe of all results that have been excluded so far
excluded_results = screening_results[(screening_results['TA_Exclude_FINAL'] == True) | (screening_results['FT_Exclude_JGE'] == True)]

# Export to CSV
excluded_results.to_csv("/".join([PROC_DATA_DIR, 'bibliography_search', 'excluded_results_jge_reviewed.csv']), index=False)

# Export results of all screening so far
screening_results.to_csv("/".join([PROC_DATA_DIR, "bibliography_search", "ft_results_jge_historical.csv"]), index=False)

# %%
# Import Zotero Data on included results.
jge_zotero_included = pd.read_csv("/".join([RAW_DATA_DIR, "full_text_screen", "full_text_zotero_included_jge.csv"]))

# Select 'Publication Year', 'Title', 'Publication Title' and 'DOI' columns from Zotero Data.
jge_zotero_included = jge_zotero_included[['Publication Year', 'Title', 'Publication Title', 'DOI']]

jge_screened_df = pd.read_csv(
    "/".join([RAW_DATA_DIR, "full_text_screen", "full_text_screen_end_jge.csv"])
)

jge_included = jge_screened_df[jge_screened_df['Exclude'] == False]

# Merge Zotero dataframe with Excel Reviewed CSV to add DOI's to Excel data.
jge_included = pd.merge(
    jge_included,
    jge_zotero_included,
    how='left',
    on=['Publication Year', 'Title', 'Publication Title']
)

# Create dataframe of results where there is no DOI.
jge_included_no_doi = jge_included[jge_included['DOI'].isna()]

# Count number of results with no DOI
jge_included_no_doi_count = len(jge_included_no_doi)

# Output number of results with no DOI
print(f"There are {jge_included_no_doi_count} results without DOI's recorded.")

jge_included['id'] = jge_included['id'].astype(int)  # Ensure id column is an integer

# Search internet for missing DOIs manually using browser. Update them here manually.
jge_included.loc[jge_included['id'] == 428, "DOI"] = "10.52916/jmrs244144"
jge_included.loc[jge_included['id'] == 484, "DOI"] = "10.14744/less.2023.45403"

# Create dataframe where DOI is NaN (blank)
jge_included_no_doi = jge_included[jge_included['DOI'].isna()]

# Count incidence where DOI is NaN
jge_included_no_doi_count = len(jge_included_no_doi)

# Output DOI NaN count
print(f"There are now {jge_included_no_doi_count} results without DOI's recorded.")

# Create list of included DOIs
jge_included_doi_list = jge_included['DOI'].tolist()

# Lists to store valid and invalid DOIs
valid_dois = {}
invalid_dois = []

# Check each DOI is valid
for doi in jge_included_doi_list:
    is_valid, title = check_doi_valid(doi)
    if is_valid:
        valid_dois[doi] = title
    else:
        invalid_dois.append(doi)
    # Pause to be polite to the API and avoid rate-limiting
    time.sleep(1)

# Print results
print("Valid DOIs and their titles:")
for doi, title in valid_dois.items():
    print(f"{doi}: {title}")

print("\nInvalid DOIs:")
for doi in invalid_dois:
    print(doi)

# Write list of valud DOIs to CSV for reference later
with open("/".join([PROC_DATA_DIR, 'bibliography_search', 'jge_included_valid_dois.csv']), 'w', newline='') as f:
    writer = csv.writer(f)
    for item in valid_dois:
        writer.writerow([item])  # Writing all items in one row

# Create a new column 'valid DOI' based on whether the DOI is in the valid_dois list
jge_included['valid DOI'] = jge_included['DOI'].apply(lambda x: x in valid_dois)
# Out:
# There are 2 results without DOI's recorded.
# There are now 0 results without DOI's recorded.
# DOI 10.1097/00019509-199802000-00016 returned status code: 404
# DOI 10.12809/eaapl81732 returned status code: 404
# Valid DOIs and their titles:
# 10.1056/NEJM188612161152403: A Case of Gastrotomy. Digital Exploration of Œsophagus, and Removal of Plate of Teeth; Recovery
# 10.1007/bf02943095: Deliberate ingestion of foreign bodies by institutionalised psychiatric hospital patients and prison inmates
# 10.1001/archsurg.1996.01430140056015: Gastrointestinal 'crosses'. A new shade from an old palette.
# 10.1136/emj.14.1.54: Oesophageal "cross"--a sinister foreign body.
# 10.1007/s003830050492: A bizarre bezoar: case report and review of the literature
# 10.1136/gut.2003.024810: Management of swallowed razor blades—retrieve or wait and see?
# 10.1016/j.jemermed.2004.03.013: A penny for your thoughts: small bowel obstruction secondary to coin ingestion.
# 10.4314/wajm.v25i3.28286: Foreign body ingestions in a schizophrenic patient.
# 10.1111/j.1368-5031.2006.00709.x: A review of gastrointestinal foreign bodies
# 10.1016/j.ejcts.2007.01.073: Aortoesophageal perforation following ingestion of razorblades with massive haemothorax.
# 10.1176/appi.psy.48.2.162: Foreign-body ingestion in patients with personality disorders.
# 10.1111/j.1463-1318.2006.01184.x: Management of foreign bodies in the rectum
# 10.1016/j.athoracsur.2007.07.027: An unusual case of a swallowed thermometer perforated in the mediastinum.
# 10.18690/actabiomed.6: The role of emergency endoscopy in upper git foreign body extraction
# 10.1097/sle.0b013e31816b78f5: Management of ingested foreign bodies. How justifiable is a waiting policy?
# 10.1016/j.gie.2008.05.072: Foreign-body ingestion: characteristics and outcomes in a lower socioeconomic population with predominantly intentional ingestion.
# 10.4253/wjge.v2.i5.186: Endoscopic removal of multiple duodenum foreign bodies: An unusual occurrence.
# 10.1016/j.cgh.2010.07.013: Intentional swallowing of foreign bodies is a recurrent and costly problem that rarely causes endoscopy complications.
# 10.4021/jocmr2009.11.1271: An Unusual Case of Foreign Body in the Anterior Abdominal Wall
# 10.1016/j.hlc.2011.01.006: Penetrating cardiac injury following sewing needle ingestion.
# 10.1016/j.genhosppsych.2011.06.011: Hard to swallow: a systematic review of deliberate foreign body ingestion.
# 10.1007/s00595-009-4362-5: Foreign bodies in the rectum: An analysis of 30 patients
# 10.1159/000338839: Successful Endoscopic Removal of a Lighter Swallowed 17 Months Before
# 10.1159/000346287: All the Wrong Places: An Unusual Case of Foreign Body Ingestion and Inhalation
# 10.1007/s00383-011-3026-x: Bowel injuries caused by ingestion of multiple magnets in children: a growing hazard
# 10.1016/j.clinimag.2011.11.017: What is the role of plain radiography in patients with foreign bodies in the gastrointestinal tract?
# 10.1097/meg.0b013e32835403d5: Endoscopy for repeatedly ingested sharp foreign bodies in patients with borderline personality disorder: an international survey
# 10.1148/rg.327125035: Radiologic findings in cases of attempted suicide and other self-injurious behavior.
# 10.1016/j.forsciint.2011.11.015: Foreign object ingestion in complex suicide: a case report and review of the literature.
# 10.1037/a0027954: Ingestion of foreign objects as a means of nonlethal self-injury.
# 10.1097/01.pra.0000426329.34149.b6: Long-Term and Bizarre Self-Injurious Behavior: An Approach to Underlying Psychological Mechanisms and Management
# 10.1016/j.jss.2013.04.078: Intentional foreign object ingestions: need for endoscopy and surgery.
# 10.1016/j.ajem.2013.10.007: Single-incision laparoscopic surgery for ingested foreign body removal.
# 10.1177/102490791502200107: Ingestion of Multiple Magnets for Suicide
# 10.4103/0976-5042.159247: The “mule” with golden eggs: Retrieval of unusual foreign body
# 10.1515/pjs-2015-0006: Foreign body in the gastrointestinal tract leading to small bowel obstruction--case report and literature review.
# 10.1055/s-0035-1569668: A deliberately swallowed foreign body: money package
# 10.1053/j.sult.2014.10.007: Nonsuicidal self-injury-related foreign bodies in the emergency department.
# 10.1055/s-0034-1390920: A game theoretic approach to repeated foreign body ingestion
# 10.1136/bcr-2014-208922: Ingested cylindrical batteries in an incarcerated male: a caustic tale!
# 10.1155/2016/8075432: Tendency to Ingest Foreign Bodies in Mentally Retarded Patients: A Case with Ileal Perforation Caused by the Ingestion of a Teaspoon
# 10.4103/2455-5568.188730: Republication: Examination of financial charges associated with intentional foreign body ingestions by prisoners: A pattern of escalation
# 10.4323/rjlm.2016.194: Self-harm in the prison system
# 10.1111/jgh.13828: Gastrointestinal: Voluntary padlock ingestion
# 10.1080/08998280.2017.11929541: Ingestion of Computer Circuit Boards Causing Esophageal Impaction and Small Bowel Obstruction
# 10.1111/psyg.12237: Analysis of inedible substance ingestion at a Japanese psychiatric hospital
# 10.1136/bcr-2017-222338: Ingestion of nine metallic nails with corrosive: what happened next?
# 10.11138/gchir/2017.38.2.080: Ingestion of foreign bodies among prisoners: a ten years retrospective study at University Hospital of Southern Italy.
# 10.1186/s12245-017-0153-8: Oesophageal coins invisible on chest radiography: a case report
# 10.1136/bcr-2017-221928: Recurrent gastric metal bezoar: a rare cause of gastric outlet obstruction
# 10.1002/ccr3.957: Gastric foreign body: a comb
# 10.4103/2455-5568.209847: Association between intentional ingestion of foreign objects and psychiatric disease among prisoners: A retrospective study
# 10.1136/bcr-2017-223182: Double duodenal perforation following foreign body ingestion
# 10.1136/bcr-2018-225241: Unusual foreign body impacted in the upper oesophagus: original technique for transoral extraction
# 10.3389/fpsyt.2018.00325: Prevalence of Deliberate Self-harm Among Chinese Patients With Heroin Dependence: A Meta-Analysis
# 10.1097/nmd.0000000000000865: Atypical and Severe Nonsuicidal Self-Injury as an Indicator of Severe Psychopathology: Findings From a Sample of High-Risk Community Mental Health Clients
# 10.1016/j.ijscr.2018.03.018: Ingested razor blades within the appendix: A rare case report
# 10.1111/sltb.12474: Self-harm by Sharp Foreign Body Ingestion.
# 10.31729/jnma.4055: Ingestion of Bell Clappers by a Shaman in Jumla, Nepal: A Case Report
# 10.1007/s11739-019-02183-4: Intentional foreign body ingestion
# 10.5812/ijpbs.85352: A Man with Nails and Needles Inside: A Case Report of Factitious Disorder
# 10.1007/s10140-018-01664-x: Digital tomosynthesis for detection of ingested foreign objects in the emergency department: a case of razor blade ingestion
# 10.12968/hmed.2019.80.9.546: Managing repeated deliberate foreign body ingestion.
# 10.1080/23772484.2018.1555436: A jackass and a fish: A case of life-threatening intentional ingestion of a live pet catfish (Corydoras aeneus)
# 10.14309/crj.0000000000000032: Nonsurgical Management of an Embedded Metal Clip in Sigmoid Colon Causing Perforation and Abscess
# 10.1155/2019/7026815: Intentional Foreign Body Ingestion: A Complex Case of Pica
# 10.1186/s12887-020-1990-9: Multicenter investigation of pediatric gastrointestinal tract magnets ingestion in China
# 10.4103/jiaps.jiaps_101_19: Multiple Atypical Esophageal Foreign Bodies in an Infant
# 10.1186/s12876-020-01224-z: Differences between intentional and accidental ingestion of foreign body in China
# 10.1542/peds.2019-1515: Preventing Self-Harm From Repeat Foreign-Body Ingestion
# 10.1097/mpg.0000000000002757: Pediatric Recurrent Intentional Foreign Body Ingestion: Case Series and Review of the Literature.
# 10.1016/j.gie.2019.09.010: Trends and clinical features of intentional and accidental adult foreign body ingestions in the United States, 2000 to 2017.
# 10.1016/j.amsu.2020.04.039: The largest esophageal foreign body in adults: A case report
# 10.7759/cureus.9336: A Child With a Gastrocolic Fistula After Ingesting Magnets: An Unusual Complication
# 10.7759/cureus.7699: Sharp Object in the Belly: A Case of Pediatric Intentional Razor Blade Ingestion in the Emergency Department
# 10.1016/j.gie.2019.10.023: Endoscopic retrieval of magnetic foreign body ingestions with a nasal bridle: description of a novel technique (with video).
# 10.12890/2020_001824: Repetitive Sharps Ingestion and Challenges with Retrieval and Prevention.
# 10.1016/j.mayocpiqo.2019.10.005: Removal of a Large Stone in the Upper Thoracic Esophagus
# 10.1093/jscr/rjaa094: Ingestion of razor blades, a rare event: a case report in a psychiatric patient
# 10.1177/11795476211025919: Intentional Ingestion of a Metallic Wire Causing Perforation and Retroperitoneal Abscess: A Case Report
# 10.1093/ehjcr/ytaa500: A case report of an unusual left atrial mass
# 10.12998/wjcc.v9.i30.9129: Unusual cervical foreign body - a neglected thermometer for 5 years: A case report
# 10.12659/ajcr.934164: Intentional Foreign Body Ingestions: A Complex, Recurrent and Costly Issue
# 10.9738/intsurg-d-15-00303.1: Intestinal perforation by ingested foreign bodies
# 10.5001/omj.2021.35: Laparoscopic Retrieval of Ingested Foreign Body
# 10.1136/flgastro-2021-101888: Crying wolf: the danger of recurrent intentional foreign body ingestion
# 10.7759/cureus.13179: Deliberate Foreign Body Ingestion in a 35-Year-Old Woman With Borderline Personality Disorder and Several Psychiatric Comorbidities
# 10.1136/bcr-2020-239022: Chronic intentional chicken bone ingestion mimicking inflammatory bowel disease
# 10.1136/bmjgast-2021-000767: An 18-year-old girl with retrosternal burning discomfort: a bitter pill to swallow
# 10.1111/1556-4029.15079: Unexpected death from hepatic abscess 16 months after toothbrush ingestion
# 10.1136/flgastro-2021-101776: Endoscopic management of intentional foreign body ingestion: experience from a UK centre
# 10.1177/0145561320937829: Unlocking Dysphagia: Intentional Ingestion of Foreign Bodies
# 10.1177/0145561320953707: An Unusually Large Object Removed From the Upper Esophagus in a Patient With Self Harm Syndrome
# 10.1016/j.jaclp.2022.10.025: (22) Multi-Disciplinary Approach to Managing Deliberate Foreign Body Ingestion on the Medical Floor
# 10.1016/j.ijscr.2022.106755: Endoscopic foreign body retrieval from the caecum – A case report and push for intervention guidelines
# 10.7759/cureus.33053: Endoscopic Retrieval of an Ingested Mobile Phone From the Stomach of a Prisoner: When Gastroenterologists Answer the Call
# 10.1016/j.amsu.2022.104747: A rare case of abdominal foreign bodies; laparoscopic removal of a sewing needle
# 10.1007/s10140-021-02009-x: Accidental or intentional ingestion of toothbrushes: experience with 8 adult patients
# 10.52916/jmrs244144: Repeated Behavior of Deliberate Foreign Body Ingestion in a Patient with Psychiatric Disorder: A Case Report
# 10.1097/mcg.0000000000001789: Effect of Delayed Endoscopy Protocol on Timing and Safety of Endoscopy for Foreign Body Ingestion and Esophageal Food Impaction
# 10.1055/a-2201-6928: Management of foreign body ingestion in adults: Time to STOP and rethink endoscopy
# 10.1097/ms9.0000000000000377: Removing 216 sharp metal foreign objects from the digestive tract of a 30-year-old male: case report
# 10.5152/tjg.2023.101123: Proceedings of the 40th National Gastroenterology Week and 11th Congress of Gastrointestinal Surgery.
# 10.1177/10398562231189431: Deliberate foreign body ingestion in patients with underlying mental illness: A retrospective multicentre study
# 10.5812/ijhrba-134720: Repeated Intentional Swallowing of Foreign Objects by an Adolescent Girl (Case Report)
# 10.1097/pra.0000000000000694: Management Challenges of Recurrent Foreign Body Ingestions in a Psychiatric Patient: A Case Report.
# 10.1136/gutjnl-2023-bsg.307: P239 Management of deliberate foreign body ingestion requiring endoscopic retrieval
# 10.4088/pcc.22cr03287: Intentional Foreign Body Ingestion in a Patient With Borderline Personality Disorder and Other Comorbidities.
# 10.34172/mejdd.2023.321: Intentional Ingestion of a Foreign Body – Why We Need Psychiatrists
# 10.7759/cureus.37677: Intentional Ingestion of Foreign Bodies: A Physician’s Agony
# 10.1093/bjs/znad348.067: EGS P21 Hard to swallow, hard to treat
# 10.1007/s00234-024-03348-5: Imaging approach to ingested foreign bodies in the neck.
# 10.1016/j.ijscr.2024.109506: A plastic bezoar causing bowel obstruction: A case of table cover ingestion
# 10.1016/j.anorl.2023.04.006: A dangerous appetite.
# 10.4328/acam.22190: Chronic foreign body ingestion in two adults with psychiatric disorder: Is it possible to wait and see?
# 10.1002/jpn3.12114: Endoscopist experience with pediatric recurrent and intentional foreign body ingestion (RIFBI): Management considerations and future directions.
# 10.1017/s0022215124000033: Difficult oesophageal foreign body removal: a novel surgical approach to a complex situation
# 10.14744/less.2023.45403: Gastrointestinal system foreign bodies
# 10.7759/cureus.58327: Esophageal Button Battery Retrieval: Time-In May Not Be Everything
#
# Invalid DOIs:
# 10.1097/00019509-199802000-00016
# 10.12809/eaapl81732

# %%
cr = Crossref()

def get_references(doi):
    """Fetch references (backward citation) for a given DOI."""
    try:
        result = cr.works(ids=doi)
        return result["message"].get("reference", [])
    except Exception as e:
        print(f"Error retrieving {doi}: {e}")
        return []

reference_list = []   # To accumulate reference dictionaries
no_reference_list = []  # To store DOIs that returned no references or errors

# Loop through each DOI in jge_included_doi_list
for doi in jge_included_doi_list:
    try:
        refs = get_references(doi)
        if refs:
            for ref in refs:
                # Extract the fields you need
                extracted_ref = {
                    "DOI": ref.get('DOI', 'No DOI provided'),
                    "author": ref.get('author', 'No Author provided'),
                    "year": ref.get('year', 'No Year provided'),
                    "journal-title": ref.get('journal-title', 'Blank'),
                    "first-page": ref.get('first-page', 'Blank'),
                    "volume": ref.get('volume', 'Blank'),
                    "unstructured": ref.get('unstructured', 'Blank')
                }
                reference_list.append(extracted_ref)
        else:
            no_reference_list.append(doi)
    except MemoryError:
        print(f"Memory error encountered while retrieving DOI: {doi}")
        no_reference_list.append(doi)
    except Exception as e:
        print(f"Error retrieving {doi}: {e}")
        no_reference_list.append(doi)
    
    # Pause briefly to reduce memory load and avoid overwhelming the API
    time.sleep(2)
    # Force garbage collection
    gc.collect()

# After processing, convert your reference list to a DataFrame
refs_df = pd.DataFrame(reference_list)

# Export to CSV.
refs_df.to_csv("/".join([RAW_DATA_DIR, 'bibliography_search', 'bibliography_search.csv']))
# Out:
# Error retrieving 10.1097/sle.0b013e31816b78f5: [Errno 12] Cannot allocate memory
# Error retrieving 10.12809/eaapl81732: Client error '404 Not Found' for url 'https://api.crossref.org/works/10.12809/eaapl81732'
# For more information check: https://developer.mozilla.org/en-US/docs/Web/HTTP/Status/404
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 42
#      39     no_reference_list.append(doi)
#      41 # Pause briefly to reduce memory load and avoid overwhelming the API
# ---> 42 time.sleep(2)
#      43 # Force garbage collection
#      44 gc.collect()
#
# KeyboardInterrupt:

# %%
def enrich_doi_data(df, doi_column="DOI"):
    # OpenAlex API Base URL
    base_url = "https://api.openalex.org/works/"
    data = []

    for doi in df[doi_column]:
        response = requests.get(base_url + "https://doi.org/" + doi)

        if response.status_code == 200:
            json_data = response.json()
            print(json_data)
            data.append({
                    "DOI": doi,
                    "Title": json_data.get("title", "N/A"),
                    "Authors": ", ".join([auth["author"]["display_name"] for auth in json_data.get("authorships", [])]) if "authorships" in json_data else "N/A",
                    "Journal": json_data.get("host_venue", {}).get("display_name", "N/A"),
                    "Publication Year": json_data.get("publication_year", "N/A"),
                    "Publisher": json_data.get("primary_location", {}).get("source", {}).get("publisher", "N/A"),
                    "Citations Count": json_data.get("cited_by_count", 0),
                    "Abstract": json_data.get("abstract", "N/A"),
                    "URL": json_data.get("id", "N/A")
                })
        else:
            data.append({
                "DOI": doi,
                "Title": "Not Found",
                "Authors": "N/A",
                "Journal": "N/A",
                "Publication Year": "N/A",
                "Publisher": "N/A",
                "Citations Count": "N/A",
                "Abstract": "N/A",
                "URL": "N/A"
            })

        time.sleep(1)  # Avoid API rate limits

    # Convert to DataFrame
    metadata_df = pd.DataFrame(data)

    # Merge with the original DataFrame
    df = df.merge(metadata_df, on="DOI", how="left")

    return df

refs_df = enrich_doi_data(refs_df)
